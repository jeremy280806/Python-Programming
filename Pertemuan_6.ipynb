# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremy280806/Python-Programming/blob/wahana/Pertemuan_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
panggil_variabel = ("mouse", "keyboard")
# rumus for
for variabel_baru in panggil_variabel:
  print(variabel_baru)
# Out:
# mouse
# keyboard

# %%
this_set = {"mouse", "keyboard", "headset", "monitor"}
print(this_set) # set berisi string hasilnya tidak urut (unindexed)
# Out:
# {'headset', 'mouse', 'keyboard', 'monitor'}

# %%
this_set = {1,2,3,4,5,6}
print(this_set) # set berisi angka hasilnya tidak urut (unindexed)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
iniset = {"meja", "kursi", "laptop", "botol", "laptop"}
print(iniset) # unordered dan unindexed = hasilnya acak
# Out:
# {'botol', 'laptop', 'kursi', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
print(iniset)
# Out:
# {False, 1, 2, 'kursi', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
for x in iniset:
  print(x)
# Out:
# False
# 1
# 2
# kursi
# meja

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
print("meja" in iniset)
# Out:
# True

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
iniset.add("laptop")
print(iniset)
# Out:
# {False, 1, 2, 'laptop', 'kursi', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
setini = {"keyboard", "monitor", "mouse"}
# iniset.update(setini)
iniset.update(["kabel", "lampu"])
print(iniset)
# Out:
# {False, 1, 2, 'kursi', 'meja', 'kabel', 'lampu'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
inituple = ("keyboard", "monitor", "mouse")
iniset.update(inituple)
print(iniset)
# Out:
# {False, 1, 2, 'keyboard', 'monitor', 'kursi', 'mouse', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
iniset.remove("kursi")
iniset.discard("meja")
print(iniset)
# Out:
# {False, 1, 2}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
iniset.pop()
print(iniset)
# Out:
# {1, 2, 'kursi', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, "Buku", "Kertas"}
a = iniset.pop()
print(a)
print(iniset)
# Out:
# 1
# {2, 'Buku', 'kursi', 'meja', 'Kertas'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
print(iniset)
# Out:
# {False, 1, 2, 'kursi', 'meja'}

# %%
iniset = {"meja", 1, True, "kursi", 2, False}
iniset.clear()
print(iniset)
# Out:
# set()

# %%
iniset1 = {"meja", 1, True, "kursi", 2, False}
set2 = {"laptop", "komputer"}
set3 = iniset1.union(set2)
print(set3)
# Out:
# {False, 1, 2, 'komputer', 'laptop', 'kursi', 'meja'}

# %%
iniset1 = {"meja", 1, True, "kursi", 2, False}
set2 = {"laptop", "komputer", "kursi"}
iniset1.intersection_update(set2)
print(iniset1)
# Out:
# {'kursi'}

# %%
iniset1 = {"meja", 1, True, "kursi", 2, False}
set2 = {"laptop", "komputer", "kursi"}
iniset1.symmetric_difference_update(set2)
print(iniset1)
# Out:
# {False, 1, 2, 'komputer', 'laptop', 'meja'}

# %%
# study kasus thrift store
set = {"mouse", "komputer", "meja"}
user_input = input("Masukkan nama barang: ")
if user_input in set:
  print("Barang ditemukan")
else:
  print("Barang tidak ditemukan")
# Out:
# Masukkan nama barang: kursi
# Barang tidak ditemukan

# %%
iniDiction = {
    "motor" : "beat",
    "warna" : "hitam",
    "warna" : "hijau",
    "tahun" : 2023
}
print(iniDiction["motor"])
print(iniDiction)
# Out:
# beat
# {'motor': 'beat', 'warna': 'hijau', 'tahun': 2023}

# %%
iniDiction = {
    "motor" : "beat",
    "warna" : "hitam",
    "warna" : "hijau",
    "tahun" : 2023
}
print(len(iniDiction))
# Out:
# 3

# %%
iniDiction = {
    "motor" : "beat",
    "warna" : ["hitam", "biru", "putih"],
    "listrik" : False,
    "tahun" : 2023
}
print(iniDiction)
print(type(iniDiction))
# Out:
# {'motor': 'beat', 'warna': ['hitam', 'biru', 'putih'], 'listrik': False, 'tahun': 2023}
# <class 'dict'>

# %%
iniDiction = dict(
    motor = "beat",
    warna = ["hitam", "biru", "putih"],
    listrik = False,
    tahun = 2023
)
print(type(iniDiction))
# Out:
# <class 'dict'>

# %%
iniDiction = {
    "motor" : "beat",
    "warna" : ["hitam", "biru", "putih"],
    "listrik" : False,
    "tahun" : 2023
}
x = iniDiction["listrik"]
y = iniDiction.get("listrik")
z = iniDiction.keys()
print(x)
print(y)
print(z)
# Out:
# False
# False
# dict_keys(['motor', 'warna', 'listrik', 'tahun'])

# %%
motor = dict(
    motor = "beat",
    warna = ["hitam", "biru", "putih"],
    listrik = False,
    tahun = 2023
)
x = motor.keys()
print(x) # sebelum ditambahkan

motor["kondisi"] = "baru"
print(x) # setelah diubah
# Out:
# dict_keys(['motor', 'warna', 'listrik', 'tahun'])
# dict_keys(['motor', 'warna', 'listrik', 'tahun', 'kondisi'])

# %%
motor = dict(
    motor = "beat",
    warna = ["hitam", "biru", "putih"],
    listrik = False,
    tahun = 2023
)
x = motor.values()
print(x)
# Out:
# dict_values(['beat', ['hitam', 'biru', 'putih'], False, 2023])

# %%
motor = dict(
    motor = "beat",
    warna = ["hitam", "biru", "putih"],
    listrik = False,
    tahun = 2023
)
x = motor.values()
print(x) # sebelum diubah

motor["tahun"] = 2024
print(x) #setelah diubah
# Out:
# dict_values(['beat', ['hitam', 'biru', 'putih'], False, 2023])
# dict_values(['beat', ['hitam', 'biru', 'putih'], False, 2024])

# %%
motor = dict(
    motor = "beat",
    warna = ["hitam", "biru", "putih"],
    listrik = False,
    tahun = 2023
)
x = motor.items()
print(x)
# Out:
# dict_items([('motor', 'beat'), ('warna', ['hitam', 'biru', 'putih']), ('listrik', False), ('tahun', 2023)])
