# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremy280806/Python-Programming/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 5, 1, 7, 9, 3, 6, 10]

x = np.array(x)
y = np.array(y)

# %%
# Build figure panjang 12 lebar 8
plt.figure(figsize=(12,8))
# scatter plot dari data asli
plt.scatter(x,y, label="Data Asli")
# Menampilkan plot
plt.show()

# %% [markdown]
# # Direct Inverse Method

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Use formula
# B = (A^T *A)^-1 * A^T * Y
# Where A = vstack (matrix_x, matri_ones).T
A = np.vstack([x, np.ones(len(x))]).T
# Ubah bentuk y dari datar jadi vertikal
y = y.reshape(-1, 1)
B = np.dot(np.dot(np.linalg.inv(np.dot(A.T, A)), A.T), y)
print(B)
# Out:
# [[0.82142857]
#  [1.67857143]]

# %% [markdown]
# # Polynomial Regression

# %%
# ax^2 + bx + c
coefficient = np.polyfit(x, y, 2)
print(coefficient)
y_pred_poly = np.polyval(coefficient,x)
print(y_pred_poly)
# Out:
# [[0.01785714]
#  [0.66071429]
#  [1.94642857]]
# [2.625      3.33928571 4.08928571 4.875      5.69642857 6.55357143
#  7.44642857 8.375     ]

# %% [markdown]
# # Pseudo-Inverse Method

# %%
# m = B[0]
# b = B[1]
# y_pred = m*x + b
# print(y_pred)

plt.figure(figsize=(10,8))
# Plot data asli
plt.scatter(x,y, label="Data Asli")
# Plot prediksi (jangan lupa plot yang pakai y hasil prediksi (jgn yg data asli))
plt.plot(x, y_pred, color='red', label="Linear Regression") #Linear
plt.plot(x, y_pred_poly, color='green', label="Polynomial Regression (degree 2)") #Quadratic

# Untuk tampilkan label di figure
plt.legend()
plt.show()

# %%
# Pseudo inverse: (A^T * A)^-1 * A^T
pinv = np.linalg.pinv(A)

# %% [markdown]
# # Cubic Spline Interpolation
# The difference between interpolation and regression is that interpolation is used to estimate values between known data points, while regression is used to estimate values outside the known data points.

# %%
from scipy.interpolate import CubicSpline
interpolate = CubicSpline(x,y)

x_new = np.linspace(1,8,100) # Membuat 100 buah titik data antara 1 - 8
y_new = interpolate(x_new) # Menyambungkan antar 100 titik data tsb

plt.figure(figsize=(10,8))
plt.scatter(x,y, label="Data Asli")
plt.plot(x, interpolate(x), color='red', label="Cubic Spline Interpolation")
plt.legend()
plt.show()
