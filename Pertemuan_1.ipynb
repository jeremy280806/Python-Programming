# %% [markdown]
# <a href="https://colab.research.google.com/github/jeremy280806/Python-Programming/blob/wahana/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# buatlah tipe data string, float, dan integer
nama = "nama saya arden" # tipe data string
umur = 20 #tipe data integer
tinggibadan = 159.5 #tipe data float

print(nama)
print(umur)
print(tinggibadan, nama)
# Out:
# nama saya arden
# 20
# 159.5 nama saya arden

# %%
umur ="20"

print(umur)
print(type(umur))

# Konversikan ke integer
umur = int("20")
print(type(umur))
print(umur)
# Out:
# 20
# <class 'str'>
# <class 'int'>
# 20

# %%
#konversi dari string ke float
umur = "20"
print(umur)

umur = float("20")
print(umur)
# Out:
# 20
# 20.0

# %%
#dari float ke string
umur = 20

umur = str(20)
print(umur)
# Out:
# 20

# %%
a, b, c = "apel", "jambi", "jeruk"

print(c)
print(a)
print(a,b)
print(a,b,c)
# Out:
# jeruk
# apel
# apel jambi
# apel jambi jeruk

# %%
#hati-hati variabel merupakan CASE SENSITIVE
n = 5
n = 7

print(n)
# Out:
# 7

# %%
#tanda (+) dapat mencetak (print) beberapa nilai yang memiliki tipe data yang sama
nama1 = " zenitha "
nama2 = " alfin "
nama3 = " bella"
print(nama1+nama2+nama3)
# Out:
#  zenitha  alfin  bella

# %%
a = "zenitha"

print("nama saya: ", a, "umur: ", 20,"tinggi badan: ", 159,5)
# Out:
# nama saya:  zenitha umur:  20 tinggi badan:  159 5

# %%
# print(f) biasanya digunakan untuk memasukkan variabel ke dalam cetakan(print)
nama = "zenitha"
umur = 20
bekerja = True
print(f"Nama saya {nama} berumur {umur} dan sudah bekerja {bekerja}")

# %%
# 2 x 4
x = 2
x *=4
print(x)
# Out:
# 8

# %%
print(3/3) #hasilnya float
print(3//3) #hasilnya integer
# Out:
# 1.0
# 1

# %%
num1 = float(input("Masukkan angka pertama: "))
num2 = float(input("Masukkan angka kedua: "))

result = (num1+num2)
print("Hasil penjumlahan: ", result)
# Out:
# Masukkan angka pertama: 1
# Masukkan angka kedua: 2
# Hasil penjumlahan:  3.0

# %%
result = "The answer is " + str(42)
print(result)
# Out:
# The answer is 42

# %%
#buatlah list yang berisi nama , kelas, dan rata-rata tinggi badan
list = ["SMA N 1 SEMARANG", 11 , 170]
print(list)
print(type(list))
# Out:
# ['SMA N 1 SEMARANG', 11, 170]
# <class 'list'>

# %%
#cara memmbaca index
bacaIndex = "sekolah negeri"

print(bacaIndex[0]) #Indeks ke-0
print(bacaIndex[0:14]) #Indeks 0-14
print(bacaIndex[4:14]) #Indeks 4-14
print(bacaIndex[8:]) #Mulai dari indeks ke-8
print(bacaIndex[:8]) #Mulai dari indeks ke-0 berakhir di indeks ke-8
# Out:
# s
# sekolah negeri
# lah negeri
# negeri
# sekolah
